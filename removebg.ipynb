# %%
# !pip install rembg
# Out:
# Collecting rembg
#   Downloading rembg-2.0.59-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (4.17.3)
# Requirement already satisfied: numpy in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (1.26.2)
# Collecting onnxruntime (from rembg)
#   Downloading onnxruntime-1.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Collecting opencv-python-headless (from rembg)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (10.0.1)
# Collecting pooch (from rembg)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting pymatting (from rembg)
#   Downloading PyMatting-1.1.13-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: scikit-image in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (0.19.3)
# Requirement already satisfied: scipy in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (1.11.4)
# Requirement already satisfied: tqdm in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from rembg) (4.66.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from jsonschema->rembg) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from jsonschema->rembg) (0.20.0)
# Collecting coloredlogs (from onnxruntime->rembg)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime->rembg)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: packaging in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from onnxruntime->rembg) (23.2)
# Requirement already satisfied: protobuf in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from onnxruntime->rembg) (4.24.4)
# Requirement already satisfied: sympy in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from onnxruntime->rembg) (1.12)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from pooch->rembg) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from pooch->rembg) (2.31.0)
# Requirement already satisfied: numba!=0.49.0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from pymatting->rembg) (0.58.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from scikit-image->rembg) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from scikit-image->rembg) (2.31.5)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from scikit-image->rembg) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from scikit-image->rembg) (1.4.1)
# Requirement already satisfied: colorama in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from tqdm->rembg) (0.4.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from numba!=0.49.0->pymatting->rembg) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2023.11.17)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ananz\miniconda3\envs\ag\lib\site-packages (from sympy->onnxruntime->rembg) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime->rembg)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading rembg-2.0.59-py3-none-any.whl (39 kB)
# Downloading onnxruntime-1.20.0-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --------- ------------------------------ 2.7/11.3 MB 86.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.0/11.3 MB 102.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 108.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---- ----------------------------------- 4.5/38.8 MB 98.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 5.4/38.8 MB 58.4 MB/s eta 0:00:01
#    -------- ------------------------------- 7.8/38.8 MB 56.0 MB/s eta 0:00:01
#    ------------- -------------------------- 13.3/38.8 MB 65.6 MB/s eta 0:00:01
#    ------------------- -------------------- 18.8/38.8 MB 108.8 MB/s eta 0:00:01
#    ------------------------- -------------- 24.3/38.8 MB 108.8 MB/s eta 0:00:01
#    ------------------------------ --------- 29.8/38.8 MB 108.8 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.8 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 81.8 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.6 MB/s eta 0:00:00
# Downloading PyMatting-1.1.13-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB ? eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------- 83.2/83.2 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, pyreadline3, opencv-python-headless, pymatting, pooch, humanfriendly, coloredlogs, onnxruntime, rembg
# Successfully installed coloredlogs-15.0.1 flatbuffers-24.3.25 humanfriendly-10.0 onnxruntime-1.20.0 opencv-python-headless-4.10.0.84 pooch-1.8.2 pymatting-1.1.13 pyreadline3-3.5.4 rembg-2.0.59

# %%
from rembg import remove
from PIL import Image
import io

input_path = 'Jpeg/Cocoa.jpg'
output_path = 'removed/outputCocoa.png'

with open(input_path, 'rb') as i:
    input_image = i.read()

output_image = remove(input_image)

with open(output_path, 'wb') as o:
    o.write(output_image)
